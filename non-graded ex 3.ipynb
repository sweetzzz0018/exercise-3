# %% [markdown]
# Create a treasure hunt game where a user has to figure out the location of the treasure on a grid by using just the commands of E, W, N, and S, indicating East, West, North, and South, respectively.
#
# REQUIREMENTS:
# 1. Define the size of the grid. It could be any number, but start from 5
# 2. Assign the player a random position on the map. Do the same for the location of the treasure. (HINT: use randint() to generate a random set of coordinates)
#     2.1. Since it's 2-dimensional grid, the location of both the player and the treasure will be coordinates, like (x,y)
# 3. Decide the maximum moves the player can make and keep track of the number of moves.
# 4. Calculate the initial distance between the player and the treasure location
# 5. Allow player to make as many moves as maximum moves allowed
#     5.1. Depending on which direction the player moves (N, S, E, or W), recalculate player's position and their distance from the treasure location
#     5.2. If the move brings player closer to the treasure, let the user know that they are getting closer
#     5.3. If the move takes player away from the treasure, let the user know that they are moving farther
#     5.4. If the player makes an illegal move, then let the user know that that move is not allowed.
#     5.5. If the new player position is the same as the treasure position, let the user know that they have found the treasure
#     5.6. If the moves made by the player are the same as maximum moves allowed, let the user know that no more moves are possible and that they have lost the game. Also show them where the treasure was located.
#     5.7. If there are still moves left, then the game should continue and keep asking the user for their moves.

# %%
import random

GRID_SIZE = 5


def generate_unique_positions():
    while True:
        player_pos = [random.randint(1, GRID_SIZE), random.randint(1, GRID_SIZE)]
        treasure_pos = [random.randint(1, GRID_SIZE), random.randint(1, GRID_SIZE)]
        if player_pos != treasure_pos:
            return player_pos, treasure_pos


def calculate_distance(player, treasure):
    return abs(player[0] - treasure[0]) + abs(player[1] - treasure[1])


def print_grid(player, treasure, reveal_treasure=False):
    for y in range(1, GRID_SIZE + 1):
        row = ""
        for x in range(1, GRID_SIZE + 1):
            if [x, y] == player:
                row += " P "  
            elif [x, y] == treasure and reveal_treasure:
                row += " T "  
            else:
                row += " . "  
        print(row)
    print()


def get_direction():
    while True:
        direction = input("Enter your move direction (N = North, S = South, E = East, W = West): ").upper()
        if direction in ["N", "S", "E", "W"]:
            return direction
        else:
            print("Invalid command, please enter N, S, E, or W.")


def move_player(player_pos, direction):
    if direction == "N" and player_pos[1] > 1:
        player_pos[1] -= 1
    elif direction == "S" and player_pos[1] < GRID_SIZE:
        player_pos[1] += 1
    elif direction == "E" and player_pos[0] < GRID_SIZE:
        player_pos[0] += 1
    elif direction == "W" and player_pos[0] > 1:
        player_pos[0] -= 1
    else:
        print("Invalid move, please try again.")
    return player_pos


def treasure_hunt():
    player_pos, treasure_pos = generate_unique_positions()
    initial_distance = calculate_distance(player_pos, treasure_pos)
    moves_made = 0
    MAX_MOVES = 10

    print(f"Your initial distance from the treasure is: {initial_distance}")

    while moves_made < MAX_MOVES:
        print_grid(player_pos, treasure_pos)
        direction = get_direction()
        player_pos = move_player(player_pos, direction)
        moves_made += 1
        new_distance = calculate_distance(player_pos, treasure_pos)

        if player_pos == treasure_pos:
            print(f"Congratulations, you found the treasure! You used {moves_made} moves.")
            print("Final map:")
            print_grid(player_pos, treasure_pos, reveal_treasure=True)  
            return
        elif new_distance < initial_distance:
            print(f"You are getting closer to the treasure! Moves remaining: {MAX_MOVES - moves_made}")
        else:
            print(f"You are getting farther from the treasure! Moves remaining: {MAX_MOVES - moves_made}")

        initial_distance = new_distance

    print(f"You have used all your moves. Game over! The treasure was located at {treasure_pos}.")
    print("Final map:")
    print_grid(player_pos, treasure_pos, reveal_treasure=True)  


treasure_hunt()
# Out:
# Your initial distance from the treasure is: 3
#  .  .  .  .  .
#  P  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#
# You are getting farther from the treasure! Moves remaining: 9
#  P  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#
# You are getting farther from the treasure! Moves remaining: 8
#  .  P  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#
# You are getting farther from the treasure! Moves remaining: 7
#  .  .  P  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#
# You are getting closer to the treasure! Moves remaining: 6
#  .  .  .  .  .
#  .  .  P  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#
# You are getting closer to the treasure! Moves remaining: 5
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  P  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#
# You are getting farther from the treasure! Moves remaining: 4
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  P  .
#  .  .  .  .  .
#  .  .  .  .  .
#
# You are getting closer to the treasure! Moves remaining: 3
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  P  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#
# You are getting closer to the treasure! Moves remaining: 2
#  .  .  .  .  .
#  .  .  .  .  .
#  .  P  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#
# You are getting closer to the treasure! Moves remaining: 1
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  P  .  .  .
#  .  .  .  .  .
#
# You are getting closer to the treasure! Moves remaining: 0
# You have used all your moves. Game over! The treasure was located at [1, 5].
# Final map:
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  .  .  .  .  .
#  T  P  .  .  .
